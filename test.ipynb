# %%
import pandas as pd

# %%
df1 = pd.read_csv('signbridge_final_demo_glosses.csv')
df1
# Out:
#            Gloss  Videos  Top-1 (%)  Top-5 (%)  Average Rank  Median Rank  \
# 0          BISON      12     100.00     100.00          1.00          1.0
# 1         EASTER      13     100.00     100.00          1.00          1.0
# 2          EIGHT      10     100.00     100.00          1.00          1.0
# 3        HUNDRED      12     100.00     100.00          1.00          1.0
# 4    INDEPENDENT      10     100.00     100.00          1.00          1.0
# 5   ORGANIZATION      13     100.00     100.00          1.00          1.0
# 6       WATERSKI      12     100.00     100.00          1.00          1.0
# 7       WORKSHOP      12     100.00     100.00          1.00          1.0
# 8          BREAK      13      92.31     100.00          1.23          1.0
# 9     DEPARTMENT      13      92.31     100.00          1.23          1.0
# 10         BADGE      12      91.67     100.00          1.08          1.0
# 11        FAMILY      12      91.67     100.00          1.17          1.0
# ...
